# %%
#raw inspection method, actual code down below

for i in range(46):
    print(i*(i+1)+1)
# Out:
# 1
# 3
# 7
# 13
# 21
# 31
# 43
# 57
# 73
# 91
# 111
# 133
# 157
# 183
# 211
# 241
# 273
# 307
# 343
# 381
# 421
# 463
# 507
# 553
# 601
# 651
# 703
# 757
# 813
# 871
# 931
# 993
# 1057
# 1123
# 1191
# 1261
# 1333
# 1407
# 1483
# 1561
# 1641
# 1723
# 1807
# 1893
# 1981
# 2071

# %%
Value_found = False
k=0
Value = 2024
while Value_found == False:
    Boundary = k*(k+1)+1
    print(Boundary)
    if Boundary >= Value:
        Value_found = True
    else:
        k=k+1


print(k)
print(Boundary)

if k % 2 == 0:
    if Value == Boundary:
        print('Right arrow')
    elif Value >= Boundary - k:
        print('Downward arrow')
    elif Value < Boundary - k:
        print('Left arrow')


elif k % 2 == 1:
    if Value == Boundary :
         print('Left arrow')
    elif Value >= Boundary - k:
        print('Upward arrow')
    elif Value < Boundary - k:
        print('Right arrow')
# Out:
# 1
# 3
# 7
# 13
# 21
# 31
# 43
# 57
# 73
# 91
# 111
# 133
# 157
# 183
# 211
# 241
# 273
# 307
# 343
# 381
# 421
# 463
# 507
# 553
# 601
# 651
# 703
# 757
# 813
# 871
# 931
# 993
# 1057
# 1123
# 1191
# 1261
# 1333
# 1407
# 1483
# 1561
# 1641
# 1723
# 1807
# 1893
# 1981
# 2071
# 45
# 2071
# Right arrow
